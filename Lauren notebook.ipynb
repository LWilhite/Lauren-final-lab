# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Lauren Wilhite**

# %% [markdown]
# Intel Analyst

# %% [markdown]
# *I am interested in data science because I want to expand my knowledge of the data science field of study*

# %% [markdown]
# ### the code produces an output

# %%
1+1
# Out:
# 2

# %% [markdown]
# > I have learned a lot of new information by taking this course

# %% [markdown]
# 1. First
# item
# 2. Second
# item
# 3. Third
# item

# %% [markdown]
# - bullet 1
# - bullet 2
# - bullet 3
